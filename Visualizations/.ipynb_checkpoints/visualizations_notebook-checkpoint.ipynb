# %%
# Add Matplotlib inline magic command
# %matplotlib inline
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
# Files to load. Here is where we will add our two datasets from database
salaries_to_load = "Resources/Salaries.csv"
people_to_load = "Resources/People.csv"
batting_to_load = "Resources/Batting.csv"

# %%
salaries_df = pd.read_csv(salaries_to_load)
salaries_df.head(10)
# Out:
#    yearID teamID lgID   playerID  salary
# 0    1985    ATL   NL  barkele01  870000
# 1    1985    ATL   NL  bedrost01  550000
# 2    1985    ATL   NL  benedbr01  545000
# 3    1985    ATL   NL   campri01  633333
# 4    1985    ATL   NL  ceronri01  625000
# 5    1985    ATL   NL  chambch01  800000
# 6    1985    ATL   NL  dedmoje01  150000
# 7    1985    ATL   NL  forstte01  483333
# 8    1985    ATL   NL  garbege01  772000
# 9    1985    ATL   NL  harpete01  250000

# %%
people_df = pd.read_csv(people_to_load)
people_df.head(10)
# Out:
#     playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 0  aardsda01     1981.0        12.0      27.0          USA         CO
# 1  aaronha01     1934.0         2.0       5.0          USA         AL
# 2  aaronto01     1939.0         8.0       5.0          USA         AL
# 3   aasedo01     1954.0         9.0       8.0          USA         CA
# 4   abadan01     1972.0         8.0      25.0          USA         FL
# 5   abadfe01     1985.0        12.0      17.0         D.R.  La Romana
# 6  abadijo01     1850.0        11.0       4.0          USA         PA
# 7  abbated01     1877.0         4.0      15.0          USA         PA
# 8  abbeybe01     1869.0        11.0      11.0          USA         VT
# 9  abbeych01     1866.0        10.0      14.0          USA         NE
#
#       birthCity  deathYear  deathMonth  deathDay nameFirst     nameLast  \
# 0        Denver        NaN         NaN       NaN     David      Aardsma
# ...

# %%
batting_df = pd.read_csv(batting_to_load)
batting_df.head(10)
# Out:
#     playerID  yearID  stint teamID lgID   G   AB   R   H  2B  ...   RBI    SB  \
# 0  abercda01    1871      1    TRO  NaN   1    4   0   0   0  ...   0.0   0.0
# 1   addybo01    1871      1    RC1  NaN  25  118  30  32   6  ...  13.0   8.0
# 2  allisar01    1871      1    CL1  NaN  29  137  28  40   4  ...  19.0   3.0
# 3  allisdo01    1871      1    WS3  NaN  27  133  28  44  10  ...  27.0   1.0
# 4  ansonca01    1871      1    RC1  NaN  25  120  29  39  11  ...  16.0   6.0
# 5  armstbo01    1871      1    FW1  NaN  12   49   9  11   2  ...   5.0   0.0
# 6  barkeal01    1871      1    RC1  NaN   1    4   0   1   0  ...   2.0   0.0
# 7  barnero01    1871      1    BS1  NaN  31  157  66  63  10  ...  34.0  11.0
# 8  barrebi01    1871      1    FW1  NaN   1    5   1   1   1  ...   1.0   0.0
# 9  barrofr01    1871      1    BS1  NaN  18   86  13  13   2  ...  11.0   1.0
#
#     CS  BB   SO  IBB  HBP  SH  SF  GIDP
# 0  0.0   0  0.0  NaN  NaN NaN NaN   0.0
# ...

# %%
# Combine the data into a single dataset
pd.set_option('display.max_columns', None)
baseball_df = pd.merge(salaries_df, batting_df, how="left", on=["playerID", "playerID"])
baseball_df
# Out:
#         yearID_x teamID_x lgID_x   playerID    salary  yearID_y  stint  \
# 0           1985      ATL     NL  barkele01    870000      1976      1
# 1           1985      ATL     NL  barkele01    870000      1977      1
# 2           1985      ATL     NL  barkele01    870000      1978      1
# 3           1985      ATL     NL  barkele01    870000      1979      1
# 4           1985      ATL     NL  barkele01    870000      1980      1
# ...          ...      ...    ...        ...       ...       ...    ...
# 320504      2016      WAS     NL  zimmery01  14000000      2015      1
# 320505      2016      WAS     NL  zimmery01  14000000      2016      1
# 320506      2016      WAS     NL  zimmery01  14000000      2017      1
# 320507      2016      WAS     NL  zimmery01  14000000      2018      1
# 320508      2016      WAS     NL  zimmery01  14000000      2019      1
#
#        teamID_y lgID_y    G   AB   R    H  2B  3B  HR    RBI   SB   CS  BB  \
# ...

# %%
# Complete year range 
baseball_df["yearID_x"].unique()
# Out:
# array([1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995,
#        1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006,
#        2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016],
#       dtype=int64)

# %%
# Set the x-axis to the year
x_axis = baseball_df['yearID_x']

# Set the y-axis to the salary
y_axis = baseball_df['salary']

# %%
# Create the plot
plt.plot(x_axis, y_axis)

# %%
avg_salaries_by_year = baseball_df.groupby(["yearID_x"]).mean()["salary"]

avg_salaries_by_year_formatted = avg_salaries_by_year.round(decimals=0)

avg_salaries_by_year_formatted
# Out:
# yearID_x
# 1985     532,996.00
# 1986     489,991.00
# 1987     509,068.00
# 1988     540,559.00
# 1989     604,102.00
# 1990     638,660.00
# 1991   1,056,533.00
# 1992   1,260,940.00
# 1993   1,226,115.00
# 1994   1,318,217.00
# 1995   1,263,714.00
# 1996   1,342,737.00
# 1997   1,558,898.00
# 1998   1,662,361.00
# 1999   1,920,348.00
# 2000   2,456,521.00
# 2001   2,866,463.00
# 2002   3,015,572.00
# 2003   3,189,847.00
# 2004   3,121,202.00
# 2005   3,317,485.00
# 2006   3,517,020.00
# 2007   3,692,028.00
# 2008   4,033,536.00
# 2009   4,047,006.00
# 2010   4,091,617.00
# 2011   4,135,400.00
# 2012   4,332,466.00
# 2013   4,717,013.00
# 2014   5,098,880.00
# 2015   5,511,780.00
# 2016   5,909,088.00
# Name: salary, dtype: float64

# %%
# Set the x-axis to the year
x_axis = baseball_df['yearID_x'].unique()

# Set the y-axis to the salary
y_axis = avg_salaries_by_year_formatted

# %%
# Create the plot
plt.plot(x_axis, y_axis)

# %%
# Create the plot.
plt.plot(x_axis, y_axis, marker="*", color="green", linewidth=2)
# Create labels for the x and y axes.
plt.xlabel("Year")
plt.ylabel("Salaries (Millions)")
# Create a title.
plt.title("Avg Salaries by Year")
# Add a grid.
plt.grid()

#Saving figure
plt.savefig("Images/avg_salaries.png")

# %%
len(pd.unique(baseball_df['teamID_x']))
# Out:
# 35

# %%
avg_ab_by_player = baseball_df.groupby(["playerID"]).mean()["AB"]

avg_ab_by_player
# Out:
# playerID
# aardsda01     0.44
# aasedo01      0.38
# abadan01      7.00
# abadfe01      0.90
# abbotje01   119.20
#              ...
# zumayjo01     0.00
# zuninmi01   278.25
# zupcibo01   159.00
# zuvelpa01    54.56
# zychto01      0.00
# Name: AB, Length: 5149, dtype: float64

# %%
# Create the Urban city DataFrame.
baseball_2016_df = baseball_df[baseball_df["yearID_x"] == 2016]
baseball_2016_df.head()
# Out:
#         yearID_x teamID_x lgID_x   playerID  salary  yearID_y  stint teamID_y  \
# 312385      2016      ARI     NL  ahmedni01  521600      2014      1      ARI
# 312386      2016      ARI     NL  ahmedni01  521600      2015      1      ARI
# 312387      2016      ARI     NL  ahmedni01  521600      2016      1      ARI
# 312388      2016      ARI     NL  ahmedni01  521600      2017      1      ARI
# 312389      2016      ARI     NL  ahmedni01  521600      2018      1      ARI
#
#        lgID_y    G   AB   R    H  2B  3B  HR   RBI   SB   CS  BB     SO  IBB  \
# 312385     NL   25   70   9   14   2   0   1  4.00 0.00 1.00   3  10.00 0.00
# 312386     NL  134  421  49   95  17   6   9 34.00 4.00 5.00  29  81.00 1.00
# 312387     NL   90  284  26   62   9   1   4 20.00 5.00 2.00  15  58.00 3.00
# 312388     NL   53  167  24   42   8   1   6 21.00 3.00 4.00  10  39.00 3.00
# 312389     NL  153  516  61  121  33   5  16 70.00 5.00 4.00  40 109.00 2.00
#
#         HBP   SH   SF  GIDP
# ...

# %%
# 
ab_count_2016 = baseball_2016_df.groupby(["teamID_x"]).mean()["AB"]
ab_count_2016.head()
# Out:
# teamID_x
# ARI   141.49
# ATL   187.18
# BAL   160.73
# BOS   179.49
# CHA   182.31
# Name: AB, dtype: float64

# %%
# Build the scatter plots for urban cities.
plt.scatter(x_axis,
      y_axis,
      s=10*avg_ab_by_player, c="coral",
      edgecolor="black", linewidths=1,
      alpha=0.8, label="ABs")
plt.title("ABs vs Salary")
plt.ylabel("Salaries (Millions)")
plt.xlabel("Avg Salaries by Year")
plt.grid(True)
# Add the legend.
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-0ab9ac8ac716> in <module>
#       4       s=10*avg_ab_by_player, c="coral",
#       5       edgecolor="black", linewidths=1,
# ----> 6       alpha=0.8, label="ABs")
#       7 plt.title("ABs vs Salary")
#       8 plt.ylabel("Salaries (Millions)")
#
# ~\anaconda3\envs\PythonData\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2814         verts=verts, edgecolors=edgecolors,
#    2815         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2816         None else {}), **kwargs)
#    2817     sci(__ret)
#    2818     return __ret
#
# ~\anaconda3\envs\PythonData\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...
