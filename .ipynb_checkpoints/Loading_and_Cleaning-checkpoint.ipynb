# %%
import pandas as pd

# %%
data_to_Load = "Teams.csv"
team_data_df = pd.read_csv(data_to_Load)

# %%
team_data_df.head()
# Out:
#    yearID lgID teamID franchID divID  Rank  Ghome DivWin WCWin LgWin WSWin  \
# 0    1871  NaN    BS1      BNA   NaN     3    NaN    NaN   NaN     N   NaN
# 1    1871  NaN    CH1      CNA   NaN     2    NaN    NaN   NaN     N   NaN
# 2    1871  NaN    CL1      CFC   NaN     8    NaN    NaN   NaN     N   NaN
# 3    1871  NaN    FW1      KEK   NaN     7    NaN    NaN   NaN     N   NaN
# 4    1871  NaN    NY2      NNA   NaN     5    NaN    NaN   NaN     N   NaN
#
#                       name                          park  attendance  BPF  \
# 0     Boston Red Stockings           South End Grounds I         NaN  103
# 1  Chicago White Stockings       Union Base-Ball Grounds         NaN  104
# 2   Cleveland Forest Citys  National Association Grounds         NaN   96
# 3     Fort Wayne Kekiongas                Hamilton Field         NaN  101
# 4         New York Mutuals      Union Grounds (Brooklyn)         NaN   90
#
#    PPF teamIDBR teamIDlahman45 teamIDretro
# 0   98      BOS            BS1         BS1
# 1  102      CHI            CH1         CH1
# 2  100      CLE            CL1         CL1
# 3  107      KEK            FW1         FW1
# 4   88      NYU            NY2         NY2

# %%
type(team_data_df)
team_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2955 entries, 0 to 2954
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   yearID          2955 non-null   int64
#  1   lgID            2905 non-null   object
#  2   teamID          2955 non-null   object
#  3   franchID        2955 non-null   object
#  4   divID           1438 non-null   object
#  5   Rank            2955 non-null   int64
#  6   Ghome           2556 non-null   float64
#  7   DivWin          1410 non-null   object
#  8   WCWin           774 non-null    object
#  9   LgWin           2927 non-null   object
#  10  WSWin           2598 non-null   object
#  11  name            2955 non-null   object
#  12  park            2921 non-null   object
#  13  attendance      2676 non-null   float64
#  14  BPF             2955 non-null   int64
#  15  PPF             2955 non-null   int64
#  16  teamIDBR        2955 non-null   object
#  17  teamIDlahman45  2955 non-null   object
#  18  teamIDretro     2955 non-null   object
# dtypes: float64(2), int64(4), object(13)
# memory usage: 438.8+ KB

# %%
team_data_df.head()
# Out:
#    yearID lgID teamID franchID divID  Rank  Ghome DivWin WCWin LgWin WSWin  \
# 0    1871  NaN    BS1      BNA   NaN     3    NaN    NaN   NaN     N   NaN
# 1    1871  NaN    CH1      CNA   NaN     2    NaN    NaN   NaN     N   NaN
# 2    1871  NaN    CL1      CFC   NaN     8    NaN    NaN   NaN     N   NaN
# 3    1871  NaN    FW1      KEK   NaN     7    NaN    NaN   NaN     N   NaN
# 4    1871  NaN    NY2      NNA   NaN     5    NaN    NaN   NaN     N   NaN
#
#                       name                          park  attendance  BPF  \
# 0     Boston Red Stockings           South End Grounds I         NaN  103
# 1  Chicago White Stockings       Union Base-Ball Grounds         NaN  104
# 2   Cleveland Forest Citys  National Association Grounds         NaN   96
# 3     Fort Wayne Kekiongas                Hamilton Field         NaN  101
# 4         New York Mutuals      Union Grounds (Brooklyn)         NaN   90
#
#    PPF teamIDBR teamIDlahman45 teamIDretro
# 0   98      BOS            BS1         BS1
# 1  102      CHI            CH1         CH1
# 2  100      CLE            CL1         CL1
# 3  107      KEK            FW1         FW1
# 4   88      NYU            NY2         NY2

# %%
#team_data_df.drop(['IgID'],['divID'],['Ghome'], axis=1, inplace=True)
team_data_df.drop(columns=['lgID','divID','Ghome','LgWin','attendance','teamIDBR','teamIDlahman45','teamIDretro'], axis=1,inplace=True)

# %%
team_data_df.head()
# Out:
#    yearID teamID franchID  Rank DivWin WCWin WSWin                     name  \
# 0    1871    BS1      BNA     3    NaN   NaN   NaN     Boston Red Stockings
# 1    1871    CH1      CNA     2    NaN   NaN   NaN  Chicago White Stockings
# 2    1871    CL1      CFC     8    NaN   NaN   NaN   Cleveland Forest Citys
# 3    1871    FW1      KEK     7    NaN   NaN   NaN     Fort Wayne Kekiongas
# 4    1871    NY2      NNA     5    NaN   NaN   NaN         New York Mutuals
#
#                            park  BPF  PPF
# 0           South End Grounds I  103   98
# 1       Union Base-Ball Grounds  104  102
# 2  National Association Grounds   96  100
# 3                Hamilton Field  101  107
# 4      Union Grounds (Brooklyn)   90   88

# %%
team_data_df.to_csv('Teams.csv')

# %%
team_data_df.columns
# Out:
# Index(['yearID', 'teamID', 'franchID', 'Rank', 'DivWin', 'WCWin', 'WSWin',
#        'name', 'park', 'BPF', 'PPF'],
#       dtype='object')

# %%
team_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2955 entries, 0 to 2954
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   yearID    2955 non-null   int64
#  1   teamID    2955 non-null   object
#  2   franchID  2955 non-null   object
#  3   Rank      2955 non-null   int64
#  4   DivWin    1410 non-null   object
#  5   WCWin     774 non-null    object
#  6   WSWin     2598 non-null   object
#  7   name      2955 non-null   object
#  8   park      2921 non-null   object
#  9   BPF       2955 non-null   int64
#  10  PPF       2955 non-null   int64
# dtypes: int64(4), object(7)
# memory usage: 254.1+ KB

# %%
from sqlalchemy import create_engine
#db_password = 'Superman78'

# %%
#db_string = f"postgres://postgres:{db_password}@127.0.0.1:5432/BaseBall_Statistics"

# %%
#engine = create_engine(db_string)

# %%
#team_data_df.to_sql(name='Teams', con=engine)

# %%
db_string = f"postgres://postgres:Superman78@127.0.0.1:5432/postgres"
engine = create_engine(db_string)
df = pd.read_sql_table("Teams", engine)
df
# Out:
#       index  yearID teamID franchID  Rank DivWin WCWin WSWin  \
# 0         0    1871    BS1      BNA     3   None  None  None
# 1         1    1871    CH1      CNA     2   None  None  None
# 2         2    1871    CL1      CFC     8   None  None  None
# 3         3    1871    FW1      KEK     7   None  None  None
# 4         4    1871    NY2      NNA     5   None  None  None
# ...     ...     ...    ...      ...   ...    ...   ...   ...
# 2950   2950    2020    SLN      STL     3      N     Y     N
# 2951   2951    2020    TBA      TBD     1      Y     N     N
# 2952   2952    2020    TEX      TEX     5      N     N     N
# 2953   2953    2020    TOR      TOR     3      N     Y     N
# 2954   2954    2020    WAS      WSN     4      N     N     N
#
#                          name                          park  BPF  PPF
# 0        Boston Red Stockings           South End Grounds I  103   98
# 1     Chicago White Stockings       Union Base-Ball Grounds  104  102
# 2      Cleveland Forest Citys  National Association Grounds   96  100
# 3        Fort Wayne Kekiongas                Hamilton Field  101  107
# 4            New York Mutuals      Union Grounds (Brooklyn)   90   88
# ...                       ...                           ...  ...  ...
# 2950      St. Louis Cardinals             Busch Stadium III   97   96
# 2951           Tampa Bay Rays               Tropicana Field   96   95
# 2952            Texas Rangers              Globe Life Field  102  102
# 2953        Toronto Blue Jays                  Sahlen Field  100   99
# 2954     Washington Nationals                Nationals Park  103  102
#
# [2955 rows x 12 columns]

# %% [markdown]
# ### Uploading csv into postgres table
# already created table in postgres now uplaoding player date

# %%
data_to_Load = "people.csv"
people_data_df = pd.read_csv(data_to_Load)

# %%
people_data_df.head()
# Out:
#     playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 0  aardsda01     1981.0        12.0      27.0          USA         CO
# 1  aaronha01     1934.0         2.0       5.0          USA         AL
# 2  aaronto01     1939.0         8.0       5.0          USA         AL
# 3   aasedo01     1954.0         9.0       8.0          USA         CA
# 4   abadan01     1972.0         8.0      25.0          USA         FL
#
#     birthCity  deathYear  deathMonth  deathDay nameFirst nameLast  \
# 0      Denver        NaN         NaN       NaN     David  Aardsma
# 1      Mobile     2021.0         1.0      22.0      Hank    Aaron
# 2      Mobile     1984.0         8.0      16.0    Tommie    Aaron
# 3      Orange        NaN         NaN       NaN       Don     Aase
# 4  Palm Beach        NaN         NaN       NaN      Andy     Abad
#
#         nameGiven  weight  height bats throws    debut finalGame
# 0     David Allan   215.0    75.0    R      R   4/6/04   8/23/15
# 1     Henry Louis   180.0    72.0    R      R  4/13/54   10/3/76
# 2      Tommie Lee   190.0    75.0    R      R  4/10/62   9/26/71
# 3  Donald William   190.0    75.0    R      R  7/26/77   10/3/90
# 4   Fausto Andres   184.0    73.0    L      L  9/10/01   4/13/06

# %%
people_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20093 entries, 0 to 20092
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   playerID      20093 non-null  object
#  1   birthYear     19979 non-null  float64
#  2   birthMonth    19811 non-null  float64
#  3   birthDay      19670 non-null  float64
#  4   birthCountry  20032 non-null  object
#  5   birthState    19561 non-null  object
#  6   birthCity     19919 non-null  object
#  7   deathYear     9887 non-null   float64
#  8   deathMonth    9886 non-null   float64
#  9   deathDay      9885 non-null   float64
#  10  nameFirst     20056 non-null  object
#  11  nameLast      20093 non-null  object
#  12  nameGiven     20056 non-null  object
#  13  weight        19277 non-null  float64
#  14  height        19357 non-null  float64
#  15  bats          18913 non-null  object
#  16  throws        19117 non-null  object
#  17  debut         19892 non-null  object
#  18  finalGame     19892 non-null  object
# dtypes: float64(8), object(11)
# memory usage: 2.9+ MB

# %%
people_data_df.to_sql(name='Player', con=engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-a3bbb93a47be> in <module>
# ----> 1 people_data_df.to_sql(name='Player', con=engine)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2776         from pandas.io import sql
#    2777
# -> 2778         sql.to_sql(
#    2779             self,
#    2780             name,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     588         )
#     589
# --> 590     pandas_sql.to_sql(
#     591         frame,
#     592         name,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1390             dtype=dtype,
#    1391         )
# -> 1392         table.create()
#    1393
#    1394         from sqlalchemy import exc
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in create(self)
#     722         if self.exists():
#     723             if self.if_exists == "fail":
# --> 724                 raise ValueError(f"Table '{self.name}' already exists.")
#     725             elif self.if_exists == "replace":
#     726                 self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'Player' already exists.

# %% [markdown]
# ### Loading Salaries.csv to clean and load into Database

# %%
data_to_Load = "Salaries.csv"
salary_data_df = pd.read_csv(data_to_Load)
salary_data_df.head()
# Out:
#    yearID teamID lgID   playerID  salary
# 0    1985    ATL   NL  barkele01  870000
# 1    1985    ATL   NL  bedrost01  550000
# 2    1985    ATL   NL  benedbr01  545000
# 3    1985    ATL   NL   campri01  633333
# 4    1985    ATL   NL  ceronri01  625000

# %%
salary_data_df.columns
# Out:
# Index(['yearID', 'teamID', 'lgID', 'playerID', 'salary'], dtype='object')

# %%
salary_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26428 entries, 0 to 26427
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   yearID    26428 non-null  int64
#  1   teamID    26428 non-null  object
#  2   lgID      26428 non-null  object
#  3   playerID  26428 non-null  object
#  4   salary    26428 non-null  int64
# dtypes: int64(2), object(3)
# memory usage: 1.0+ MB

# %%
#LOAD the csv/dataFrame into the table
salary_data_df.to_sql(name='Salary', con=engine)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-04b01e7c043c> in <module>
#       1 #LOAD the csv/dataFrame into the table
# ----> 2 salary_data_df.to_sql(name='Salary', con=engine)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2776         from pandas.io import sql
#    2777
# -> 2778         sql.to_sql(
#    2779             self,
#    2780             name,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     588         )
#     589
# --> 590     pandas_sql.to_sql(
#     591         frame,
#     592         name,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1390             dtype=dtype,
#    1391         )
# -> 1392         table.create()
#    1393
#    1394         from sqlalchemy import exc
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/sql.py in create(self)
#     722         if self.exists():
#     723             if self.if_exists == "fail":
# --> 724                 raise ValueError(f"Table '{self.name}' already exists.")
#     725             elif self.if_exists == "replace":
#     726                 self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'Salary' already exists.

# %%
data_to_Load = "AwardsPlayers.csv"
awards_data_df = pd.read_csv(data_to_Load)
awards_data_df.head()
# Out:
#     playerID                awardID  yearID lgID  tie notes
# 0   bondto01  Pitching Triple Crown    1877   NL  NaN   NaN
# 1  hinespa01           Triple Crown    1878   NL  NaN   NaN
# 2  heckegu01  Pitching Triple Crown    1884   AA  NaN   NaN
# 3  radboch01  Pitching Triple Crown    1884   NL  NaN   NaN
# 4  oneilti01           Triple Crown    1887   AA  NaN   NaN

# %%
awards_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6236 entries, 0 to 6235
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   playerID  6236 non-null   object
#  1   awardID   6236 non-null   object
#  2   yearID    6236 non-null   int64
#  3   lgID      6235 non-null   object
#  4   tie       49 non-null     object
#  5   notes     4768 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 292.4+ KB

# %%
#LOAD the csv/dataFrame into the table
awards_data_df.to_sql(name='Awards', con=engine)

# %%
#CLEAN and LOAD AllStar
data_to_Load = "AllStarFull.csv"
allStar_data_df = pd.read_csv(data_to_Load)
allStar_data_df.head()
# Out:
#     playerID  yearID  gameNum        gameID teamID lgID  GP  startingPos
# 0  gomezle01  1933.0      0.0  ALS193307060    NYA   AL   1          1.0
# 1  ferreri01  1933.0      0.0  ALS193307060    BOS   AL   1          2.0
# 2  gehrilo01  1933.0      0.0  ALS193307060    NYA   AL   1          3.0
# 3  gehrich01  1933.0      0.0  ALS193307060    DET   AL   1          4.0
# 4  dykesji01  1933.0      0.0  ALS193307060    CHA   AL   1          5.0

# %%
#verify dataype for postgres
allStar_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5375 entries, 0 to 5374
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   playerID     5375 non-null   object
#  1   yearID       5374 non-null   float64
#  2   gameNum      5374 non-null   float64
#  3   gameID       5325 non-null   object
#  4   teamID       5375 non-null   object
#  5   lgID         5375 non-null   object
#  6   GP           5375 non-null   int64
#  7   startingPos  1691 non-null   float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 336.1+ KB

# %%
#LOAD the csv/dataFrame into the table
allStar_data_df.to_sql(name='AllStar', con=engine)
